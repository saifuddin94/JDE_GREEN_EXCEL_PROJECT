# %%
import tweepy
import pandas as pd

# %%
# Credentials

consumer_key = 'frxFyJskSPkPvxiMu8NKUfvX8'

consumer_secret = 'tCtujcAsHIZF8TSzDxKCBJbfM75v8vNEzClmuA48nSqpnC0PH0'

access_token = '557446265-KT2R47ApGYDLiLMDjbYTQONxhctzAtdhbZRm39SE'

access_token_secret = 'nYaLC8D3KzHPcKCRNIoNclAEiMDZ5mROmCqpZZsyheAxb'


auth = tweepy.OAuthHandler(consumer_key, consumer_secret)

auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

# %%
user = api.get_user('JoeBiden')


print(user.id_str)
print("The name is : " + user.name)
print("The screen_name is : " + user.screen_name)
print("The location is : " + str(user.location))
print("The profile_location is : " + str(user.profile_location))
print("The description is : " + user.description)
# Out:
# 939091
# The name is : Joe Biden
# The screen_name is : JoeBiden
# The location is : Washington, DC
# The profile_location is : None
# The description is : Husband to @DrBiden, proud father and grandfather. Ready to build back better for all Americans. Official account is @POTUS.

# %%
number_of_tweets = 500
tweets = []
likes = []
time = []

for i in tweepy.Cursor(api.user_timeline, id='JoeBiden', tweet_mode = 'extended').items(number_of_tweets):
    tweets.append(i.full_text)
    likes.append(i.favorite_count)
    time.append(i.created_at)
    
df = pd.DataFrame({'tweets': tweets, 'likes': likes, 'time': time})

# %%
df
# Out:
#                                                tweets  likes  \
# 0   We have a path to usher in a new era of econom...  28667
# 1   RT @POTUS: My Build Back Better Agenda and the...      0
# 2   The Bipartisan Infrastructure Deal and the Bui...  22141
# 3   This is the moment to make sure all of us—not ...  20624
# 4   Our Build Back Better Agenda will strengthen o...  15555
# ..                                                ...    ...
# 95  RT @POTUS: I will be addressing the nation on ...      0
# 96  Our economy is coming back—but there’s more wo...  91800
# 97  RT @POTUS: In what is already a challenging ti...      0
# 98  While we will have ups and downs along the way...  11869
# 99  Today, about 40 million families will receive ...  20688
#
#                   time
# 0  2021-09-30 00:06:02
# 1  2021-09-29 23:51:17
# 2  2021-09-29 21:49:00
# 3  2021-09-29 18:48:22
# 4  2021-09-28 22:50:01
# ..                 ...
# 95 2021-08-16 15:09:25
# 96 2021-08-14 22:46:00
# 97 2021-08-14 22:23:03
# 98 2021-08-14 16:59:16
# 99 2021-08-13 13:58:00
#
# [100 rows x 3 columns]
